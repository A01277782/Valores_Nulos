# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Plazas.xlsx')
df.head(5)
# Out:
#           Fecha Origen                  Nombre  Telefono Producto  \
# 0  2025-05-06 18:30:00    Alejandro Fernandez        NaN     AION
# 1  2025-05-06 18:00:00           David Israel        NaN    EMKOO
# 2  2025-05-06 13:50:00          Rosendo Ceron        NaN   EMZOOM
# 3  2025-05-06 13:47:00  Fausto Ochoa Martinez        NaN   EMZOOM
# 4  2025-05-06 13:43:00      Brigida Lara Perez       NaN   EMZOOM
#
#                             Asesor               Origen  Seguimiento  \
# 0         NANCY OLASCOAGA CASTILLO    PLAZA ANGELOPOLIS          1.0
# 1       JOSE EDUARDO  PARADA DURAN    PLAZA ANGELOPOLIS          1.0
# 2  MAURICIO ALFREDO VAZQUEZ FARFAN  Gran Patio Tlaxcala          1.0
# 3  MAURICIO ALFREDO VAZQUEZ FARFAN  Gran Patio Tlaxcala          1.0
# 4  MAURICIO ALFREDO VAZQUEZ FARFAN  Gran Patio Tlaxcala          1.0
#
#    Cita efetiva   PDM  SDC     Estatus ¿Por que no hay seguimiento?  \
# 0            0.0  0.0  0.0  Contactado           Si hay seguimiento
# ...

# %%
df = pd.read_excel('Plazas.xlsx')
df.tail(5)
# Out:
#                 Fecha Origen                    Nombre  Telefono Producto  \
# 1048569  2025-06-09 15:30:00      Miguel Fernandez           NaN      GS8
# 1048570  2025-06-09 13:15:00                  Luis           NaN   EMZOOM
# 1048571  2025-06-09 13:14:00       Rolando Manrique          NaN   EMZOOM
# 1048572  2025-06-09 12:50:00  Odilia Cuamatzi Bautista       NaN      GS8
# 1048573  2025-05-24 12:19:22             Raul Jimenez        NaN   EMZOOM
#
#                                   Asesor               Origen  Seguimiento  \
# 1048569     PEDRO ANTONIO CINTO DE GANTE    PLAZA ANGELOPOLIS          0.0
# 1048570  SERGIO RAYMUNDO VAZQUEZ SANCHEZ    GALERIAS TLAXCALA          0.0
# 1048571  SERGIO RAYMUNDO VAZQUEZ SANCHEZ  Gran Patio Tlaxcala          0.0
# 1048572  MAURICIO ALFREDO VAZQUEZ FARFAN  Gran Patio Tlaxcala          0.0
# 1048573              RICARDO SILVA HERAS    PLAZA ANGELOPOLIS          1.0
#
# ...

# %%
valores_nulos = df.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                1048272
# Nombre                                      1048271
# Telefono                                    1048574
# Producto                                    1048271
# Asesor                                      1048271
# Origen                                      1048271
# Seguimiento                                       7
# Cita efetiva                                     10
# PDM                                              11
# SDC                                              11
# Estatus                                           7
# ¿Por que no hay seguimiento?                1048375
# ¿Por que no ha visitado la agencia?         1048405
# ¿Por que no hubo prueba de manejo ?         1048546
# ¿Por que no hubo solicitud de credito?      1048547
# ¿Por que no se ha formalizado la compra?    1048560
# Unnamed: 16                                 1048550
# Unnamed: 17                                 1048574
# ...

# %%
#Se eliminaron columnas innecesarias
df1= df.drop(['Telefono', 'Unnamed: 16','Unnamed: 17','Unnamed: 18', 'Unnamed: 19' ], axis=1)
df1
# Out:
#                 Fecha Origen                    Nombre Producto  \
# 0        2025-05-06 18:30:00      Alejandro Fernandez      AION
# 1        2025-05-06 18:00:00             David Israel     EMKOO
# 2        2025-05-06 13:50:00            Rosendo Ceron    EMZOOM
# 3        2025-05-06 13:47:00    Fausto Ochoa Martinez    EMZOOM
# 4        2025-05-06 13:43:00        Brigida Lara Perez   EMZOOM
# ...                      ...                       ...      ...
# 1048569  2025-06-09 15:30:00      Miguel Fernandez          GS8
# 1048570  2025-06-09 13:15:00                  Luis       EMZOOM
# 1048571  2025-06-09 13:14:00       Rolando Manrique      EMZOOM
# 1048572  2025-06-09 12:50:00  Odilia Cuamatzi Bautista      GS8
# 1048573  2025-05-24 12:19:22             Raul Jimenez    EMZOOM
#
#                                   Asesor               Origen  Seguimiento  \
# 0               NANCY OLASCOAGA CASTILLO    PLAZA ANGELOPOLIS          1.0
# ...

# %%
valores_nulos = df1.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                1048272
# Nombre                                      1048271
# Producto                                    1048271
# Asesor                                      1048271
# Origen                                      1048271
# Seguimiento                                       7
# Cita efetiva                                     10
# PDM                                              11
# SDC                                              11
# Estatus                                           7
# ¿Por que no hay seguimiento?                1048375
# ¿Por que no ha visitado la agencia?         1048405
# ¿Por que no hubo prueba de manejo ?         1048546
# ¿Por que no hubo solicitud de credito?      1048547
# ¿Por que no se ha formalizado la compra?    1048560
# dtype: int64

# %%
df.shape
# Out:
# (1048574, 20)

# %%
df2 = df1.iloc[0:280, 0:20]
df3 = df1.iloc[1048550:1048576, 0:20]

# %%
df_final = pd.concat([df2, df3], ignore_index=True)

# %%
df_final
# Out:
#             Fecha Origen                    Nombre Producto  \
# 0    2025-05-06 18:30:00      Alejandro Fernandez      AION
# 1    2025-05-06 18:00:00             David Israel     EMKOO
# 2    2025-05-06 13:50:00            Rosendo Ceron    EMZOOM
# 3    2025-05-06 13:47:00    Fausto Ochoa Martinez    EMZOOM
# 4    2025-05-06 13:43:00        Brigida Lara Perez   EMZOOM
# ..                   ...                       ...      ...
# 299  2025-06-09 15:30:00      Miguel Fernandez          GS8
# 300  2025-06-09 13:15:00                  Luis       EMZOOM
# 301  2025-06-09 13:14:00       Rolando Manrique      EMZOOM
# 302  2025-06-09 12:50:00  Odilia Cuamatzi Bautista      GS8
# 303  2025-05-24 12:19:22             Raul Jimenez    EMZOOM
#
#                               Asesor               Origen  Seguimiento  \
# 0           NANCY OLASCOAGA CASTILLO    PLAZA ANGELOPOLIS          1.0
# 1         JOSE EDUARDO  PARADA DURAN    PLAZA ANGELOPOLIS          1.0
# ...

# %%
valores_nulos = df_final.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                  4
# Nombre                                        3
# Producto                                      3
# Asesor                                        3
# Origen                                        3
# Seguimiento                                   7
# Cita efetiva                                  9
# PDM                                          10
# SDC                                           9
# Estatus                                       7
# ¿Por que no hay seguimiento?                107
# ¿Por que no ha visitado la agencia?         136
# ¿Por que no hubo prueba de manejo ?         276
# ¿Por que no hubo solicitud de credito?      277
# ¿Por que no se ha formalizado la compra?    290
# dtype: int64

# %%
#Sustituir valores nulos por una fecha ficticia
df_final["Fecha Origen"] =df_final["Fecha Origen"].fillna("2030-06-19 00:00:00")

# %%
valores_nulos = df_final.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                  0
# Nombre                                        3
# Producto                                      3
# Asesor                                        3
# Origen                                        3
# Seguimiento                                   7
# Cita efetiva                                  9
# PDM                                          10
# SDC                                           9
# Estatus                                       7
# ¿Por que no hay seguimiento?                107
# ¿Por que no ha visitado la agencia?         136
# ¿Por que no hubo prueba de manejo ?         276
# ¿Por que no hubo solicitud de credito?      277
# ¿Por que no se ha formalizado la compra?    290
# dtype: int64

# %%
#Sustiruir valor nulo por texto 
df_final["Nombre"] =df_final["Nombre"].fillna("No se registro nombre")

# %%
valores_nulos = df_final.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                  0
# Nombre                                        0
# Producto                                      3
# Asesor                                        3
# Origen                                        3
# Seguimiento                                   7
# Cita efetiva                                  9
# PDM                                          10
# SDC                                           9
# Estatus                                       7
# ¿Por que no hay seguimiento?                107
# ¿Por que no ha visitado la agencia?         136
# ¿Por que no hubo prueba de manejo ?         276
# ¿Por que no hubo solicitud de credito?      277
# ¿Por que no se ha formalizado la compra?    290
# dtype: int64

# %%
#Sustiruir valor nulo por texto 
df_final["Producto"] =df_final["Producto"].fillna("No se registro producto")

# %%
valores_nulos = df_final.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                  0
# Nombre                                        0
# Producto                                      0
# Asesor                                        3
# Origen                                        3
# Seguimiento                                   7
# Cita efetiva                                  9
# PDM                                          10
# SDC                                           9
# Estatus                                       7
# ¿Por que no hay seguimiento?                107
# ¿Por que no ha visitado la agencia?         136
# ¿Por que no hubo prueba de manejo ?         276
# ¿Por que no hubo solicitud de credito?      277
# ¿Por que no se ha formalizado la compra?    290
# dtype: int64

# %%
#Sustiruir valor nulo por texto 
df_final["Asesor"] =df_final["Asesor"].fillna("No se registro Asesor")

# %%
valores_nulos = df_final.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                  0
# Nombre                                        0
# Producto                                      0
# Asesor                                        0
# Origen                                        3
# Seguimiento                                   7
# Cita efetiva                                  9
# PDM                                          10
# SDC                                           9
# Estatus                                       7
# ¿Por que no hay seguimiento?                107
# ¿Por que no ha visitado la agencia?         136
# ¿Por que no hubo prueba de manejo ?         276
# ¿Por que no hubo solicitud de credito?      277
# ¿Por que no se ha formalizado la compra?    290
# dtype: int64

# %%
#Sustiruir valor nulo por texto 
df_final["Origen"] =df_final["Origen"].fillna("No hay registro")

# %%
valores_nulos = df_final.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                  0
# Nombre                                        0
# Producto                                      0
# Asesor                                        0
# Origen                                        0
# Seguimiento                                   7
# Cita efetiva                                  9
# PDM                                          10
# SDC                                           9
# Estatus                                       7
# ¿Por que no hay seguimiento?                107
# ¿Por que no ha visitado la agencia?         136
# ¿Por que no hubo prueba de manejo ?         276
# ¿Por que no hubo solicitud de credito?      277
# ¿Por que no se ha formalizado la compra?    290
# dtype: int64

# %%
#Sustiruir valor nulo por texto 
df_final["Seguimiento"] =df_final["Seguimiento"].fillna("No hay registro")

# %%
valores_nulos = df_final.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                  0
# Nombre                                        0
# Producto                                      0
# Asesor                                        0
# Origen                                        0
# Seguimiento                                   0
# Cita efetiva                                  9
# PDM                                          10
# SDC                                           9
# Estatus                                       7
# ¿Por que no hay seguimiento?                107
# ¿Por que no ha visitado la agencia?         136
# ¿Por que no hubo prueba de manejo ?         276
# ¿Por que no hubo solicitud de credito?      277
# ¿Por que no se ha formalizado la compra?    290
# dtype: int64

# %%
#Sustiruir valor nulo por texto 
df_final["Cita efetiva "] =df_final["Cita efetiva "].fillna("No se registro")

# %%
valores_nulos = df_final.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                  0
# Nombre                                        0
# Producto                                      0
# Asesor                                        0
# Origen                                        0
# Seguimiento                                   0
# Cita efetiva                                  0
# PDM                                          10
# SDC                                           9
# Estatus                                       7
# ¿Por que no hay seguimiento?                107
# ¿Por que no ha visitado la agencia?         136
# ¿Por que no hubo prueba de manejo ?         276
# ¿Por que no hubo solicitud de credito?      277
# ¿Por que no se ha formalizado la compra?    290
# dtype: int64

# %%
#Sustiruir valor nulo por texto 
df_final["PDM"] =df_final["PDM"].fillna("No se registro")

# %%
valores_nulos = df_final.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                  0
# Nombre                                        0
# Producto                                      0
# Asesor                                        0
# Origen                                        0
# Seguimiento                                   0
# Cita efetiva                                  0
# PDM                                           0
# SDC                                           9
# Estatus                                       7
# ¿Por que no hay seguimiento?                107
# ¿Por que no ha visitado la agencia?         136
# ¿Por que no hubo prueba de manejo ?         276
# ¿Por que no hubo solicitud de credito?      277
# ¿Por que no se ha formalizado la compra?    290
# dtype: int64

# %%
#Sustiruir valor nulo por texto 
df_final["SDC"] =df_final["SDC"].fillna("No se registro")

# %%
valores_nulos = df_final.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                  0
# Nombre                                        0
# Producto                                      0
# Asesor                                        0
# Origen                                        0
# Seguimiento                                   0
# Cita efetiva                                  0
# PDM                                           0
# SDC                                           0
# Estatus                                       7
# ¿Por que no hay seguimiento?                107
# ¿Por que no ha visitado la agencia?         136
# ¿Por que no hubo prueba de manejo ?         276
# ¿Por que no hubo solicitud de credito?      277
# ¿Por que no se ha formalizado la compra?    290
# dtype: int64

# %%
#Sustiruir valor nulo por texto 
df_final["Estatus"] =df_final["Estatus"].fillna("No hay registro")

# %%
valores_nulos = df_final.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                  0
# Nombre                                        0
# Producto                                      0
# Asesor                                        0
# Origen                                        0
# Seguimiento                                   0
# Cita efetiva                                  0
# PDM                                           0
# SDC                                           0
# Estatus                                       0
# ¿Por que no hay seguimiento?                107
# ¿Por que no ha visitado la agencia?         136
# ¿Por que no hubo prueba de manejo ?         276
# ¿Por que no hubo solicitud de credito?      277
# ¿Por que no se ha formalizado la compra?    290
# dtype: int64

# %%
#Sustiruir valor nulo por texto 
df_final["¿Por que no hay seguimiento?"] =df_final["¿Por que no hay seguimiento?"].fillna("No hay registro") 
df_final["¿Por que no ha visitado la agencia?"] =df_final["¿Por que no ha visitado la agencia?"].fillna("No hay registro") 
df_final["¿Por que no hubo prueba de manejo ?"] =df_final["¿Por que no hubo prueba de manejo ?"].fillna("No hay registro") 
df_final["¿Por que no hubo solicitud de credito?"] =df_final["¿Por que no hubo solicitud de credito?"].fillna("No hay registro") 
df_final["¿Por que no se ha formalizado la compra?"] =df_final["¿Por que no se ha formalizado la compra?"].fillna("No hay registro")

# %%
valores_nulos = df_final.isnull().sum()
valores_nulos
# Out:
# Fecha Origen                                0
# Nombre                                      0
# Producto                                    0
# Asesor                                      0
# Origen                                      0
# Seguimiento                                 0
# Cita efetiva                                0
# PDM                                         0
# SDC                                         0
# Estatus                                     0
# ¿Por que no hay seguimiento?                0
# ¿Por que no ha visitado la agencia?         0
# ¿Por que no hubo prueba de manejo ?         0
# ¿Por que no hubo solicitud de credito?      0
# ¿Por que no se ha formalizado la compra?    0
# dtype: int64

# %%
#Convertir DataFrame a CSV
df_final.to_csv("Plazas_SinNulos.csv")
