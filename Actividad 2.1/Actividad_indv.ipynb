# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Citas_Digital_Filtrado.csv')
df.head(5)
# Out:
#     BDC  Fecha Nombre Cliente  Telefono  Estatus de Lead Potencial de compra  \
# 0  Saul    NaN      Guillermo        NaN     Finalizado                  0.9
# 1  Saul    NaN        Roberto        NaN     Finalizado                  0.4
# 2  Saul    NaN         Irving        NaN     Finalizado                 0.85
# 3  Saul    NaN        Oswaldo        NaN          Venta                  0.9
# 4  Saul    NaN        Rodrigo        NaN     Finalizado                  0.9
#
#    PDM  SDC  Venta Asesor Asignado  \
# 0  1.0  0.0    0.0           Nancy
# 1  0.0  0.0    0.0         Victor
# 2  0.0  0.0    0.0           Alan
# 3  0.0  0.0    1.0       Mauricio
# 4  1.0  0.0    0.0       Mauricio
#
#                  ¿Por que no ha visitado la agencia?  \
# 0  Ya visito la Agencia  el dia jueves 17, intere...
# 1           Ya visito la Agencia  el dia 3 de abril
# 2           Ya visito la agencia el dia 21 de abril
# 3            El cliente vive en Tabasco Villahermosa
# ...

# %%
#Se eliminaron columnas innecesarias (Unnamed:15)
df1= df.drop(['Unnamed: 15'], axis=1)
df1
# Out:
#          BDC        Fecha             Nombre Cliente  Telefono   \
# 0       Saul          NaN                  Guillermo        NaN
# 1       Saul          NaN                    Roberto        NaN
# 2       Saul          NaN                     Irving        NaN
# 3       Saul          NaN                    Oswaldo        NaN
# 4       Saul          NaN                    Rodrigo        NaN
# ..        ...         ...                         ...       ...
# 671       Ana  2026-07-22             Maira Escalante       NaN
# 672  Ignacio   2026-07-22                Zaira Macip        NaN
# 673  Ignacio   2026-07-27            Julio Hernandez        NaN
# 674  Ignacio   2026-07-24           Xhunaxhi Vicente        NaN
# 675  Ignacio   2026-07-29  DR Jairo Rodriguez Farias        NaN
#
#     Estatus de Lead Potencial de compra  PDM  SDC  Venta Asesor Asignado  \
# 0       Finalizado                  0.9  1.0  0.0    0.0           Nancy
# ...

# %%
valores_nulos = df.isnull().sum()
valores_nulos
# Out:
# BDC                                          16
# Fecha                                       601
# Nombre Cliente                               21
# Telefono                                    674
# Estatus de Lead                              35
# Potencial de compra                          74
# PDM                                           1
# SDC                                           2
# Venta                                         5
# Asesor Asignado                              32
# ¿Por que no ha visitado la agencia?         183
# ¿Por que no hay solicitud de credito?       297
# ¿Por que no hubo prueba de manejo ?         321
# ¿Por que no hubo proceso wow?               312
# ¿Por que se asigno antes de vistar piso?    323
# Unnamed: 15                                 660
# dtype: int64

# %%
df2 = df1.copy()

# %%
#Se sustituyeron los valores nulos por valores no nulos hacia adelante 
df2["BDC "] = df2["BDC "].ffill()

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                           0
# Fecha                                       601
# Nombre Cliente                               21
# Telefono                                    674
# Estatus de Lead                              35
# Potencial de compra                          74
# PDM                                           1
# SDC                                           2
# Venta                                         5
# Asesor Asignado                              32
# ¿Por que no ha visitado la agencia?         183
# ¿Por que no hay solicitud de credito?       297
# ¿Por que no hubo prueba de manejo ?         321
# ¿Por que no hubo proceso wow?               312
# ¿Por que se asigno antes de vistar piso?    323
# dtype: int64

# %%
#Se sustiuyo valores nulos por una fecha ficticia
df2["Fecha"] =df2["Fecha"].fillna("2030-06-19 00:00:00")

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                           0
# Fecha                                         0
# Nombre Cliente                               21
# Telefono                                    674
# Estatus de Lead                              35
# Potencial de compra                          74
# PDM                                           1
# SDC                                           2
# Venta                                         5
# Asesor Asignado                              32
# ¿Por que no ha visitado la agencia?         183
# ¿Por que no hay solicitud de credito?       297
# ¿Por que no hubo prueba de manejo ?         321
# ¿Por que no hubo proceso wow?               312
# ¿Por que se asigno antes de vistar piso?    323
# dtype: int64

# %%
#Se sustituyeron los valores nulos por valores no nulos hacia adelante 
df2["Nombre Cliente "] = df2["Nombre Cliente "].ffill()

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                           0
# Fecha                                         0
# Nombre Cliente                                0
# Telefono                                    674
# Estatus de Lead                              35
# Potencial de compra                          74
# PDM                                           1
# SDC                                           2
# Venta                                         5
# Asesor Asignado                              32
# ¿Por que no ha visitado la agencia?         183
# ¿Por que no hay solicitud de credito?       297
# ¿Por que no hubo prueba de manejo ?         321
# ¿Por que no hubo proceso wow?               312
# ¿Por que se asigno antes de vistar piso?    323
# dtype: int64

# %%
#se sustituyeron los valores nulos de telefono por texto de "no identificado"
df2["Telefono "] =df2["Telefono "].fillna("No identificado")

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                           0
# Fecha                                         0
# Nombre Cliente                                0
# Telefono                                      0
# Estatus de Lead                              35
# Potencial de compra                          74
# PDM                                           1
# SDC                                           2
# Venta                                         5
# Asesor Asignado                              32
# ¿Por que no ha visitado la agencia?         183
# ¿Por que no hay solicitud de credito?       297
# ¿Por que no hubo prueba de manejo ?         321
# ¿Por que no hubo proceso wow?               312
# ¿Por que se asigno antes de vistar piso?    323
# dtype: int64

# %%
#Se sustituyeron los valores nulos por valores no nulos hacia adelante 
df2["Estatus de Lead"] = df2["Estatus de Lead"].ffill()

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                           0
# Fecha                                         0
# Nombre Cliente                                0
# Telefono                                      0
# Estatus de Lead                               0
# Potencial de compra                          74
# PDM                                           1
# SDC                                           2
# Venta                                         5
# Asesor Asignado                              32
# ¿Por que no ha visitado la agencia?         183
# ¿Por que no hay solicitud de credito?       297
# ¿Por que no hubo prueba de manejo ?         321
# ¿Por que no hubo proceso wow?               312
# ¿Por que se asigno antes de vistar piso?    323
# dtype: int64

# %%
#se cambiaron los valores a float
df2['Potencial de compra'].unique

df2['Potencial de compra']=df2['Potencial de compra'].astype("string")
df2['Potencial de compra']=df2['Potencial de compra'].str.replace("Ventas ","0", regex=False)
df2['Potencial de compra']=df2['Potencial de compra'].str.replace("%","", regex=False)
df2['Potencial de compra']=df2['Potencial de compra'].str.replace("'","", regex=False)
df2['Potencial de compra']=df2['Potencial de compra'].str.replace("&","", regex=False)

df2['Potencial de compra']=df2['Potencial de compra'].astype(float)

# %%
#Sustituir valores nulos con promedio o media
df2["Potencial de compra"]=df2["Potencial de compra"].fillna(round(df2["Potencial de compra"].mean(),1))

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                           0
# Fecha                                         0
# Nombre Cliente                                0
# Telefono                                      0
# Estatus de Lead                               0
# Potencial de compra                           0
# PDM                                           1
# SDC                                           2
# Venta                                         5
# Asesor Asignado                              32
# ¿Por que no ha visitado la agencia?         183
# ¿Por que no hay solicitud de credito?       297
# ¿Por que no hubo prueba de manejo ?         321
# ¿Por que no hubo proceso wow?               312
# ¿Por que se asigno antes de vistar piso?    323
# dtype: int64

# %%
#Sustituir valores nulos con promedio o media
df2["Venta"]=df2["Venta"].fillna(round(df2["Venta"].mean(),1))

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                           0
# Fecha                                         0
# Nombre Cliente                                0
# Telefono                                      0
# Estatus de Lead                               0
# Potencial de compra                           0
# PDM                                           1
# SDC                                           2
# Venta                                         0
# Asesor Asignado                              32
# ¿Por que no ha visitado la agencia?         183
# ¿Por que no hay solicitud de credito?       297
# ¿Por que no hubo prueba de manejo ?         321
# ¿Por que no hubo proceso wow?               312
# ¿Por que se asigno antes de vistar piso?    323
# dtype: int64

# %%
#se sustituyeron los valores nulos de Asesor por texto de "Asesor no identificado"
df2["Asesor Asignado"] =df2["Asesor Asignado"].fillna("Asesor no identificado")

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                           0
# Fecha                                         0
# Nombre Cliente                                0
# Telefono                                      0
# Estatus de Lead                               0
# Potencial de compra                           0
# PDM                                           1
# SDC                                           2
# Venta                                         0
# Asesor Asignado                               0
# ¿Por que no ha visitado la agencia?         183
# ¿Por que no hay solicitud de credito?       297
# ¿Por que no hubo prueba de manejo ?         321
# ¿Por que no hubo proceso wow?               312
# ¿Por que se asigno antes de vistar piso?    323
# dtype: int64

# %%
#se sustituyeron los valores nulos de ¿Por que no ha visitado la agencia? por texto de "No resgistro razón"
df2["¿Por que no ha visitado la agencia?"] =df2["¿Por que no ha visitado la agencia?"].fillna("No resgistro razón")

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                           0
# Fecha                                         0
# Nombre Cliente                                0
# Telefono                                      0
# Estatus de Lead                               0
# Potencial de compra                           0
# PDM                                           1
# SDC                                           2
# Venta                                         0
# Asesor Asignado                               0
# ¿Por que no ha visitado la agencia?           0
# ¿Por que no hay solicitud de credito?       297
# ¿Por que no hubo prueba de manejo ?         321
# ¿Por que no hubo proceso wow?               312
# ¿Por que se asigno antes de vistar piso?    323
# dtype: int64

# %%
#se sustituyeron los valores nulos de ¿Por que no hay solicitud de credito? por texto de "No resgistro razón"
df2["¿Por que no hay solicitud de credito?"] =df2["¿Por que no hay solicitud de credito?"].fillna("No resgistro razón")

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                           0
# Fecha                                         0
# Nombre Cliente                                0
# Telefono                                      0
# Estatus de Lead                               0
# Potencial de compra                           0
# PDM                                           1
# SDC                                           2
# Venta                                         0
# Asesor Asignado                               0
# ¿Por que no ha visitado la agencia?           0
# ¿Por que no hay solicitud de credito?         0
# ¿Por que no hubo prueba de manejo ?         321
# ¿Por que no hubo proceso wow?               312
# ¿Por que se asigno antes de vistar piso?    323
# dtype: int64

# %%
#se sustituyeron los valores nulos de ¿Por que no hubo prueba de manejo ? por texto de "No resgistro razón"
df2["¿Por que no hubo prueba de manejo ?"] =df2["¿Por que no hubo prueba de manejo ?"].fillna("No resgistro razón")

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                           0
# Fecha                                         0
# Nombre Cliente                                0
# Telefono                                      0
# Estatus de Lead                               0
# Potencial de compra                           0
# PDM                                           1
# SDC                                           2
# Venta                                         0
# Asesor Asignado                               0
# ¿Por que no ha visitado la agencia?           0
# ¿Por que no hay solicitud de credito?         0
# ¿Por que no hubo prueba de manejo ?           0
# ¿Por que no hubo proceso wow?               312
# ¿Por que se asigno antes de vistar piso?    323
# dtype: int64

# %%
#se sustituyeron los valores nulos de ¿Por que no hubo proceso wow? por texto de "No resgistro razón"
df2["¿Por que no hubo proceso wow?"] =df2["¿Por que no hubo proceso wow?"].fillna("No resgistro razón")

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                           0
# Fecha                                         0
# Nombre Cliente                                0
# Telefono                                      0
# Estatus de Lead                               0
# Potencial de compra                           0
# PDM                                           1
# SDC                                           2
# Venta                                         0
# Asesor Asignado                               0
# ¿Por que no ha visitado la agencia?           0
# ¿Por que no hay solicitud de credito?         0
# ¿Por que no hubo prueba de manejo ?           0
# ¿Por que no hubo proceso wow?                 0
# ¿Por que se asigno antes de vistar piso?    323
# dtype: int64

# %%
#se sustituyeron los valores nulos de ¿Por que se asigno antes de vistar piso?  por texto de "No resgistro razón"
df2["¿Por que se asigno antes de vistar piso?"] =df2["¿Por que se asigno antes de vistar piso?"].fillna("No resgistro razón")

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                         0
# Fecha                                       0
# Nombre Cliente                              0
# Telefono                                    0
# Estatus de Lead                             0
# Potencial de compra                         0
# PDM                                         1
# SDC                                         2
# Venta                                       0
# Asesor Asignado                             0
# ¿Por que no ha visitado la agencia?         0
# ¿Por que no hay solicitud de credito?       0
# ¿Por que no hubo prueba de manejo ?         0
# ¿Por que no hubo proceso wow?               0
# ¿Por que se asigno antes de vistar piso?    0
# dtype: int64

# %%
#Sustituir valores nulos con promedio o media
df2["SDC"]=df2["SDC"].fillna(round(df2["SDC"].median(),1))

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                         0
# Fecha                                       0
# Nombre Cliente                              0
# Telefono                                    0
# Estatus de Lead                             0
# Potencial de compra                         0
# PDM                                         1
# SDC                                         0
# Venta                                       0
# Asesor Asignado                             0
# ¿Por que no ha visitado la agencia?         0
# ¿Por que no hay solicitud de credito?       0
# ¿Por que no hubo prueba de manejo ?         0
# ¿Por que no hubo proceso wow?               0
# ¿Por que se asigno antes de vistar piso?    0
# dtype: int64

# %%
#Sustituir valores nulos con promedio o media
df2["PDM"]=df2["PDM"].fillna(round(df2["PDM"].median(),1))

# %%
valores_nulos = df2.isnull().sum()
valores_nulos
# Out:
# BDC                                         0
# Fecha                                       0
# Nombre Cliente                              0
# Telefono                                    0
# Estatus de Lead                             0
# Potencial de compra                         0
# PDM                                         0
# SDC                                         0
# Venta                                       0
# Asesor Asignado                             0
# ¿Por que no ha visitado la agencia?         0
# ¿Por que no hay solicitud de credito?       0
# ¿Por que no hubo prueba de manejo ?         0
# ¿Por que no hubo proceso wow?               0
# ¿Por que se asigno antes de vistar piso?    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 16 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   BDC                                       660 non-null    str
#  1   Fecha                                     75 non-null     str
#  2   Nombre Cliente                            655 non-null    str
#  3   Telefono                                  2 non-null      str
#  4   Estatus de Lead                           641 non-null    str
#  5   Potencial de compra                       602 non-null    str
#  6   PDM                                       675 non-null    float64
#  7   SDC                                       674 non-null    float64
#  8   Venta                                     671 non-null    float64
#  9   Asesor Asignado                           644 non-null    str
# ...

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   BDC                                       676 non-null    str
#  1   Fecha                                     676 non-null    str
#  2   Nombre Cliente                            676 non-null    str
#  3   Telefono                                  676 non-null    str
#  4   Estatus de Lead                           676 non-null    str
#  5   Potencial de compra                       676 non-null    float64
#  6   PDM                                       676 non-null    float64
#  7   SDC                                       676 non-null    float64
#  8   Venta                                     676 non-null    float64
#  9   Asesor Asignado                           676 non-null    str
# ...

# %%
#Convertir DataFrame a CSV
df2.to_csv("Citas_Digital_Filtrado2.csv")
